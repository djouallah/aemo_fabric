# %%
# !pip install -q semantic-link
import requests
url = "https://github.com/djouallah/aemo_fabric/raw/main/model.tmsl"
resp = requests.get(url)
model= resp.text
import sempy.fabric as fabric
fabric.execute_tmsl(workspace="demo",script=model)
# Out:
# StatementMeta(, 5b37fe34-8ea2-45c7-910a-9cf19ef11d8e, 3, Finished, Available)
